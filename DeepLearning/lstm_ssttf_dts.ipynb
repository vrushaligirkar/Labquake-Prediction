# %% [markdown]
# LSTM model for predicting filtered shear stress and time to failure
#
#
#
# > Input: Features at previous p timesteps with an interval of 10 [(t-10*p), ... , (t-20), (t-10), t]
#
# > Output: Shear Stress and TTF at one timestep [t]

# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler

# %%
# Function to create data with timesteps

## The input will be 10 samples apart
## Example (for n_steps=2): input indices = 0,10,20 
##                          input timesteps = 200.1, 200.2, 200.3   (instead of 200.1, 200.11, 200.12)

def create_timesteps(data, n_steps):
  x = []
  y = []
  for i in range(len(data)):
    end_ix = i + n_steps
    if end_ix > len(data):
      break
    samps = np.arange(i,end_ix,10)
    x1, y1 = data[samps, :-2], data[samps[-1], -2:]  #last two columns is assumed to be the target variable
    x.append(x1)
    y.append(y1)
  return np.array(x), np.array(y)

# %%
# Load the data

data = loadmat('/content/drive/My Drive/Colab Notebooks/Labquake_prediction/MLpreprocessed_code/data/p5270_ML_Master.mat')

m_t = pd.DataFrame({'Time':data['Time'].ravel().round(2),  'SS':data['SS'].ravel(), 'TTF':data['TTF'].ravel()})  
a_t = pd.DataFrame({'Time':data['LocalAcTime'].ravel().round(2), 'A_filt':data['A_filt'].ravel(), 'V_filt':data['V_filt'].ravel(),
                    'T_pc':data['T_pc'].ravel(), 'Vel_pc':data['Vel_pc'].ravel(), 'T_der':data['T_der'].ravel(), 'Vel_der':data['Vel_der'].ravel()})  

df = a_t.merge(m_t, on='Time')

print("Input data: ", df.shape)
# Out:
# Input data:  (132399, 9)

# %%
# Preprocessing

df = df.drop(['Time', 'Vel_der', 'T_der'], axis=1)   # Drop irrelevant features

arr = df.to_numpy()
n_steps = 300
xdf, ydf = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape, Y = ', np.shape(ydf))
# Out:
# Features shape, X =  (132100, 30, 4)
# Target shape, Y =  (132100, 2)

# %%
# Split into train-val-test
x_train, x_test, y_train, y_test = train_test_split(xdf, ydf, test_size=0.2, shuffle=False)
X_train, X_val, Y_train, Y_val = train_test_split(x_train, y_train, test_size=0.1, shuffle=False)

# Normalize the features
scaler = MinMaxScaler()
num_instances, num_time_steps, num_features = X_train.shape
X_train = scaler.fit_transform(np.reshape(X_train, (-1, num_features)))
X_train = np.reshape(X_train, (num_instances, num_time_steps, num_features))

num_instances, num_time_steps, num_features = X_val.shape
X_val = scaler.transform(np.reshape(X_val, (-1, num_features)))
X_val = np.reshape(X_val, (num_instances, num_time_steps, num_features))

num_instances, num_time_steps, num_features = x_test.shape
x_test = scaler.transform(np.reshape(x_test, (-1, num_features)))
x_test = np.reshape(x_test, (num_instances, num_time_steps, num_features))

print("Training:", np.shape(X_train))
print("Validation:", np.shape(X_val))
print("Testing:", np.shape(x_test))
# Out:
# Training: (95112, 30, 4)
# Validation: (10568, 30, 4)
# Testing: (26420, 30, 4)

# %%
# Build the model

np.random.seed(0)   # To get reproducible results
#tf.random.set_seed(1)

out_dim = ydf.shape[1]

inp = Input(shape=(X_train.shape[1], X_train.shape[2]), name='inp')
m = LSTM(128, activation='relu', kernel_initializer='normal')(inp)
m = Dense(64, kernel_initializer='normal', activation='relu')(m)
ss = Dense(1, kernel_initializer='normal', activation='linear', name='ss')(m)
ttf = Dense(1, kernel_initializer='normal', activation='linear', name='ttf')(m)
model = Model(inputs=[inp], outputs=[ss,ttf])

losses = {'ss': 'mse', 'ttf':'mse'}
losswts = {'ss': 1.0, 'ttf': 0.5}

model.compile(loss=losses, loss_weights=losswts, optimizer='adam')

start_time = time.time()
history = model.fit(X_train, {'ss':Y_train[:,0], 'ttf':Y_train[:,1]}, epochs=20, batch_size=32, 
                    validation_data=(X_val, {'ss':Y_val[:,0], 'ttf':Y_val[:,1]}), verbose=1)
end_time = time.time()

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/20
# 2973/2973 [==============================] - 138s 46ms/step - loss: 0.9751 - ss_loss: 0.6976 - ttf_loss: 0.5549 - val_loss: 0.0941 - val_ss_loss: 0.0047 - val_ttf_loss: 0.1788
# Epoch 2/20
# 2973/2973 [==============================] - 136s 46ms/step - loss: 0.0646 - ss_loss: 0.0036 - ttf_loss: 0.1220 - val_loss: 0.0701 - val_ss_loss: 0.0036 - val_ttf_loss: 0.1330
# Epoch 3/20
# 2973/2973 [==============================] - 135s 45ms/step - loss: 0.0503 - ss_loss: 0.0027 - ttf_loss: 0.0953 - val_loss: 0.0892 - val_ss_loss: 0.0012 - val_ttf_loss: 0.1760
# Epoch 4/20
# 2973/2973 [==============================] - 134s 45ms/step - loss: 0.0447 - ss_loss: 0.0020 - ttf_loss: 0.0853 - val_loss: 0.0591 - val_ss_loss: 0.0016 - val_ttf_loss: 0.1150
# Epoch 5/20
# 2973/2973 [==============================] - 133s 45ms/step - loss: 0.0401 - ss_loss: 0.0016 - ttf_loss: 0.0771 - val_loss: 0.0537 - val_ss_loss: 7.6798e-04 - val_ttf_loss: 0.1058
# Epoch 6/20
# 2973/2973 [==============================] - 132s 44ms/step - loss: 0.0371 - ss_loss: 0.0013 - ttf_loss: 0.0715 - val_loss: 0.0514 - val_ss_loss: 0.0013 - val_ttf_loss: 0.1002
# Epoch 7/20
# 2973/2973 [==============================] - 132s 44ms/step - loss: 0.0342 - ss_loss: 0.0011 - ttf_loss: 0.0663 - val_loss: 0.0612 - val_ss_loss: 8.3219e-04 - val_ttf_loss: 0.1208
# Epoch 8/20
# 2973/2973 [==============================] - 132s 44ms/step - loss: 0.0330 - ss_loss: 9.5644e-04 - ttf_loss: 0.0640 - val_loss: 0.0434 - val_ss_loss: 5.9682e-04 - val_ttf_loss: 0.0856
# Epoch 9/20
# 2973/2973 [==============================] - 130s 44ms/step - loss: 0.0312 - ss_loss: 8.1756e-04 - ttf_loss: 0.0608 - val_loss: 0.0463 - val_ss_loss: 8.4187e-04 - val_ttf_loss: 0.0910
# Epoch 10/20
# 2973/2973 [==============================] - 131s 44ms/step - loss: 0.0305 - ss_loss: 7.8593e-04 - ttf_loss: 0.0594 - val_loss: 0.0531 - val_ss_loss: 5.4716e-04 - val_ttf_loss: 0.1051
# Epoch 11/20
# 2973/2973 [==============================] - 136s 46ms/step - loss: 0.0297 - ss_loss: 7.4803e-04 - ttf_loss: 0.0579 - val_loss: 0.0557 - val_ss_loss: 7.2538e-04 - val_ttf_loss: 0.1100
# Epoch 12/20
# 2973/2973 [==============================] - 140s 47ms/step - loss: 0.0286 - ss_loss: 6.5277e-04 - ttf_loss: 0.0558 - val_loss: 0.0458 - val_ss_loss: 4.2371e-04 - val_ttf_loss: 0.0908
# Epoch 13/20
# 2973/2973 [==============================] - 138s 46ms/step - loss: 0.0280 - ss_loss: 6.6651e-04 - ttf_loss: 0.0546 - val_loss: 0.0392 - val_ss_loss: 4.6372e-04 - val_ttf_loss: 0.0775
# Epoch 14/20
# 2973/2973 [==============================] - 143s 48ms/step - loss: 0.0268 - ss_loss: 5.7645e-04 - ttf_loss: 0.0525 - val_loss: 0.0454 - val_ss_loss: 4.6951e-04 - val_ttf_loss: 0.0898
# Epoch 15/20
# 2973/2973 [==============================] - 141s 48ms/step - loss: 0.0261 - ss_loss: 5.6872e-04 - ttf_loss: 0.0510 - val_loss: 0.0423 - val_ss_loss: 3.6332e-04 - val_ttf_loss: 0.0838
# Epoch 16/20
# 2973/2973 [==============================] - 137s 46ms/step - loss: 0.0257 - ss_loss: 5.4214e-04 - ttf_loss: 0.0504 - val_loss: 0.0484 - val_ss_loss: 6.0978e-04 - val_ttf_loss: 0.0956
# Epoch 17/20
# 2973/2973 [==============================] - 137s 46ms/step - loss: 0.0247 - ss_loss: 5.1329e-04 - ttf_loss: 0.0483 - val_loss: 0.0467 - val_ss_loss: 6.4235e-04 - val_ttf_loss: 0.0920
# Epoch 18/20
# 2973/2973 [==============================] - 136s 46ms/step - loss: 0.0243 - ss_loss: 4.7628e-04 - ttf_loss: 0.0476 - val_loss: 0.0418 - val_ss_loss: 6.4854e-04 - val_ttf_loss: 0.0823
# Epoch 19/20
# 2973/2973 [==============================] - 136s 46ms/step - loss: 0.0249 - ss_loss: 4.9175e-04 - ttf_loss: 0.0488 - val_loss: 0.0393 - val_ss_loss: 8.3125e-04 - val_ttf_loss: 0.0770
# Epoch 20/20
# 2973/2973 [==============================] - 146s 49ms/step - loss: 0.0237 - ss_loss: 4.5194e-04 - ttf_loss: 0.0465 - val_loss: 0.0418 - val_ss_loss: 5.3776e-04 - val_ttf_loss: 0.0825
# ---Training time: 2724.20649338 seconds ---

# %%
print(model.summary())
plot_model(model, show_shapes=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inp (InputLayer)                [(None, 30, 4)]      0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 128)          68096       inp[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        lstm[0][0]
# __________________________________________________________________________________________________
# ss (Dense)                      (None, 1)            65          dense[0][0]
# __________________________________________________________________________________________________
# ttf (Dense)                     (None, 1)            65          dense[0][0]
# ==================================================================================================
# Total params: 76,482
# Trainable params: 76,482
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Evaluate the model

y_predTrain = model.predict(X_train)
y_predTrain[1] = np.clip(y_predTrain[1].ravel(), a_min=0,a_max=None)
ss_train_r2 = r2_score(Y_train[:,0], y_predTrain[0])
ss_train_rmse = np.sqrt(mean_squared_error(Y_train[:,0], y_predTrain[0]))
ttf_train_r2 = r2_score(Y_train[:,1], y_predTrain[1])
ttf_train_rmse = np.sqrt(mean_squared_error(Y_train[:,1], y_predTrain[1]))

y_predVal = model.predict(X_val)
y_predVal[1] = np.clip(y_predVal[1].ravel(), a_min=0,a_max=None)
ss_val_r2 = r2_score(Y_val[:,0], y_predVal[0])
ss_val_rmse = np.sqrt(mean_squared_error(Y_val[:,0], y_predVal[0]))  
ttf_val_r2 = r2_score(Y_val[:,1], y_predVal[1])
ttf_val_rmse = np.sqrt(mean_squared_error(Y_val[:,1], y_predVal[1]))

start_time = time.time()
y_predTest = model.predict(x_test)
end_time = time.time()
y_predTest[1] = np.clip(y_predTest[1].ravel(), a_min=0,a_max=None)
ss_test_r2 = r2_score(y_test[:,0], y_predTest[0])
ss_test_rmse = np.sqrt(mean_squared_error(y_test[:,0], y_predTest[0]))
ttf_test_r2 = r2_score(y_test[:,1], y_predTest[1])
ttf_test_rmse = np.sqrt(mean_squared_error(y_test[:,1], y_predTest[1]))

print("Shear Stress\nR2 scores: Train - %0.5f, Validation - %0.5f, Test - %0.5f" %(ss_train_r2, ss_val_r2, ss_test_r2))
print("RMSE scores: Train - %0.5f, Validation - %0.5f, Test - %0.5f" %(ss_train_rmse, ss_val_rmse, ss_test_rmse))

print("\nTTF\nR2 scores: Train - %0.5f, Validation - %0.5f, Test - %0.5f" %(ttf_train_r2, ttf_val_r2, ttf_test_r2))
print("RMSE scores: Train - %0.5f, Validation - %0.5f, Test - %0.5f" %(ttf_train_rmse, ttf_val_rmse, ttf_test_rmse))

print("\n---Time for Test data prediction: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Shear Stress
# R2 scores: Train - 0.97629, Validation - 0.97521, Test - 0.93830
# RMSE scores: Train - 0.01979, Validation - 0.02319, Test - 0.03591
#
# TTF
# R2 scores: Train - 0.96224, Validation - 0.93798, Test - 0.91046
# RMSE scores: Train - 0.20368, Validation - 0.28667, Test - 0.34370
#
# ---Time for Test data prediction: 3.63551450 seconds ---

# %%
# Results plot

def results_plot(fig_no, gt, pred, title, ylabel):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(gt)
  plt.plot(pred)
  plt.xlabel('Samples')
  plt.ylabel(ylabel)
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, Y_train[:,0], y_predTrain[0], 'Training data', 'Shear Stress')
results_plot(2, Y_val[:,0], y_predVal[0], 'Validation data', 'Shear Stress')
results_plot(3, y_test[:,0], y_predTest[0], 'Testing data', 'Shear Stress')
results_plot(4, Y_train[:,1], y_predTrain[1], 'Training data', 'TTF')
results_plot(5, Y_val[:,1], y_predVal[1], 'Validation data', 'TTF')
results_plot(6, y_test[:,1], y_predTest[1], 'Testing data', 'TTF')

# %%
# Detailed view of SS plots

n=5000

fig = plt.figure(4, figsize=(20,6))
plt.plot(Y_train[-n:,0])
plt.plot(y_predTrain[0][-n:])
plt.xlabel('Sample')
plt.ylabel('Shear Stress')
plt.legend(['Ground truth', 'Predicted'])
plt.title('Detailed View, Training Data')

fig = plt.figure(5, figsize=(20,6))
plt.plot(Y_val[:n,0])
plt.plot(y_predVal[0][:n])
plt.xlabel('Sample')
plt.ylabel('Shear Stress')
plt.legend(['Ground truth', 'Predicted'])
plt.title('Detailed View, Validation Data')

fig = plt.figure(6, figsize=(20,6))
plt.plot(y_test[:n,0])
plt.plot(y_predTest[0][:n])
plt.xlabel('Samples')
plt.ylabel('Shear Stress')
plt.legend(['Ground truth', 'Predicted'])
plt.title('Detailed View, Testing Data')
# Out:
# Text(0.5, 1.0, 'Detailed View, Testing Data')

# %%
# Detailed view of TTF plots

n=5000

fig = plt.figure(4, figsize=(20,6))
plt.plot(Y_train[-n:,1])
plt.plot(y_predTrain[1][-n:])
plt.xlabel('Sample')
plt.ylabel('TTF')
plt.legend(['Ground truth', 'Predicted'])
plt.title('Detailed View, Training Data')

fig = plt.figure(5, figsize=(20,6))
plt.plot(Y_val[:n,1])
plt.plot(y_predVal[1][:n])
plt.xlabel('Sample')
plt.ylabel('TTF')
plt.legend(['Ground truth', 'Predicted'])
plt.title('Detailed View, Validation Data')

fig = plt.figure(6, figsize=(20,6))
plt.plot(y_test[:n,1])
plt.plot(y_predTest[1][:n])
plt.xlabel('Sample')
plt.ylabel('TTF')
plt.legend(['Ground truth', 'Predicted'])
plt.title('Detailed View, Testing Data')
# Out:
# Text(0.5, 1.0, 'Detailed View, Testing Data')

# %%
# Regression analysis
fig = plt.figure(7, figsize=(10,10))
plt.plot(Y_train[:,0], Y_train[:,0], 'black')
plt.scatter(Y_train[:,0], y_predTrain[0], s=3)
plt.scatter(Y_val[:,0], y_predVal[0], s=3)
plt.scatter(y_test[:,0], y_predTest[0], s=3)
plt.xlabel('Observed')
plt.ylabel('Predicted')
plt.legend(['1:1 Line','Train', 'Validation', 'Test'])
plt.title('Shear Stress')

fig = plt.figure(8, figsize=(10,10))
plt.plot(Y_train[:,1], Y_train[:,1], 'black')
plt.scatter(Y_train[:,1], y_predTrain[1], s=3)
plt.scatter(Y_val[:,1], y_predVal[1], s=3)
plt.scatter(y_test[:,1], y_predTest[1], s=3)
plt.xlabel('Observed')
plt.ylabel('Predicted')
plt.legend(['1:1 Line','Train', 'Validation', 'Test'])
plt.title('TTF')
# Out:
# Text(0.5, 1.0, 'TTF')
